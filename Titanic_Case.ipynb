# %% [markdown]
# <a href="https://colab.research.google.com/github/mz33-babu/machine-learning/blob/main/Titanic_Case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Titanic Prediction
#
# Who gets to live and who gets to die.
#
# Procedure:
# 1. Data Obtainance
# 2. Data wrangling
# 3. Data visualization
# 4. Feature Engineering
# 5. Modeling
# 6. Deployment

# %% [markdown]
# # Data Obtainance
#
# Here we obtain our data

# %%
# Importing necessary libraries
import pandas as pd

# %%
# Load data
titanic_df = pd.read_csv('/content/train.csv')

# %%
# View data
titanic_df.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 501          502         0       3                Canavan, Miss. Mary  female
# 119          120         0       3  Andersson, Miss. Ellis Anna Maria  female
# 808          809         0       2                  Meyer, Mr. August    male
# 72            73         0       2               Hood, Mr. Ambrose Jr    male
# 770          771         0       3             Lievens, Mr. Rene Aime    male
# 200          201         0       3     Vande Walle, Mr. Nestor Cyriel    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 826          827         0       3                       Lam, Mr. Len    male
# 94            95         0       3                  Coxon, Mr. Daniel    male
# 361          362         0       2          del Carlo, Mr. Sebastiano    male
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Data Wrangling
# Cleaning data and making it ready for use to give insights through visualization and useful for training the models
#
# We will check for:
# 1. Incomplete data (Missing Data)
# 2. Duplicated data
# 3. Skewed data
# 4. Outliers
# 5. Inconsistent Data (format)
# 6. Imbalanced data
